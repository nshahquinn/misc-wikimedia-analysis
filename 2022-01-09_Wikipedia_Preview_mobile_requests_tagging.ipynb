# %%
import pandas as pd

import wmfdata as wmf

# %%
views = wmf.spark.run("""
SELECT
    SUM(CAST(is_pageview AS INT)) AS pageviews,
    SUM(CAST(NOT is_pageview AS INT)) AS previews,
    year,
    month,
    day,
    access_method,
    x_analytics_map["wprov"] = "wppw1t" AS has_touch_parameter,
    parse_url(referer, 'HOST') AS referer_host
FROM wmf.webrequest
WHERE
    x_analytics_map["wprov"] IN ('wppw1', 'wppw1t')
    AND webrequest_source = 'text'
    AND year = 2022
GROUP BY
    year,
    month,
    day,
    access_method,
    x_analytics_map["wprov"] = "wppw1t",
    parse_url(referer, 'HOST')
""", session_type="yarn-large")
# Out:
# PySpark executors will use /usr/lib/anaconda-wmf/bin/python3.
# 22/01/10 01:22:51 WARN Utils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.debug.maxToStringFields' in SparkEnv.conf.

# %%
views["time"] = pd.to_datetime(views[["year", "month", "day"]])

# %%
touch_parameter_previews = views.query("has_touch_parameter and referer_host not in ('0.0.0.0', 'localhost')")
touch_parameter_previews
# Out:
#      pageviews  previews  year  month  day access_method  has_touch_parameter  \
# 8            0         1  2022      1    5       desktop                 True
# 49           0         1  2022      1    5       desktop                 True
# 58           0         3  2022      1    6       desktop                 True
# 132          0         4  2022      1    8       desktop                 True
# 138          0         1  2022      1    8       desktop                 True
# 149          0         1  2022      1    9       desktop                 True
# 226          0         1  2022      1    8       desktop                 True
# 241          0         5  2022      1    8       desktop                 True
# 250          0         3  2022      1    8       desktop                 True
# 278          0         1  2022      1    9       desktop                 True
# 281          0         9  2022      1    4       desktop                 True
#
#                     referer_host       time
# 8          rightforeducation.org 2022-01-05
# 49           sanremo-festival.de 2022-01-05
# 58              mindfull.monster 2022-01-06
# 132        buildasmarterhome.com 2022-01-08
# 138       hedendaagsesieraden.nl 2022-01-08
# 149             afanporsaber.com 2022-01-09
# 226    college-emile-durkheim.fr 2022-01-08
# 241  pk-andrianakis.lima-city.de 2022-01-08
# 250               www.gomcqs.net 2022-01-08
# 278               www.gomcqs.net 2022-01-09
# 281        diegochillo.github.io 2022-01-04

# %%
touch_parameter_previews.groupby("time")["previews"].sum()
# Out:
# time
# 2022-01-04     9
# 2022-01-05     2
# 2022-01-06     3
# 2022-01-08    14
# 2022-01-09     2
# Name: previews, dtype: int64

# %%
(
    views
    .groupby(["time", "has_touch_parameter"])
    ["previews"]
    .sum()
    .to_frame()
    .unstack()
    .fillna(0)
    .applymap(int)
    .rename_axis()
    .droplevel(0, axis="columns")
)
# Out:
# has_touch_parameter  False  True
# time
# 2022-01-01             301     0
# 2022-01-02             317     0
# 2022-01-03             301    10
# 2022-01-04             547    30
# 2022-01-05             579     2
# 2022-01-06             466     3
# 2022-01-07             424     0
# 2022-01-08             392    14
# 2022-01-09             502     2
# 2022-01-10              14     0
