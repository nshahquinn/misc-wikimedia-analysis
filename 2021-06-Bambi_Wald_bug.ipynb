# %%
import bambi
import pandas as pd

# %%
df = pd.DataFrame({
    "y": [
        1.3541332,
        1.6383834,
        0.18503332,
        0.9468333,
        3.7527165,
        0.11376667,
        3.14105,
        1.1191167,
        0.27975,
        0.262025,
        0.221975,
        0.17823334,
        0.15044999,
        1.0397834,
        0.18265,
        3.0455317,
        14.627583,
        1.3326833,
        1.5818334,
        1.3684334,
        0.77771664,
        0.6055833,
        0.19428332,
        10.471216,
        0.4987417,
        0.80578333,
        0.8698499,
        1.3923234,
        6.166725,
        17.586184,
        5.469328,
        1.74125,
        7.7819333,
        6.883298,
        3.6082916,
        0.15126666,
        0.06893334,
        2.4083834,
        2.09726,
        1.3534334,
        0.32255,
        2.5490665,
        0.45341668,
        2.5404,
        3.5278418,
        0.63198334,
        0.122933336,
        1.1794333,
        0.292375,
        0.26621667,
        0.58718336,
        1.7400666,
        3.9555867,
        0.93508327,
        0.78256667,
        1.2098167,
        1.1254,
        0.90753335,
        0.5651389,
        1.1920667,
        2.64955,
        0.5711833,
        0.6519667,
        0.16675,
        0.9109583,
        3.0179832,
        1.4953833,
        0.3624,
        3.6342168,
        0.7247,
        0.07805,
        0.8059,
        5.0333724,
        2.4251168,
        1.50525,
        0.15815,
        6.587042,
        0.51663333,
        12.1748,
        0.78239167,
        5.1398168,
        8.67445,
        0.25989583,
        0.6013333,
        1.2397166,
        2.9462373,
        10.222825,
        1.0564055,
        0.63345,
        2.278475,
        9.5802355,
        0.31390333,
        0.42168334,
        0.4487,
        5.3615417,
        0.49438334,
        0.8344333,
        9.268833,
        0.25476667,
        1.37915
    ],
    "x": [
        "A",
        "A",
        "A",
        "A",
        "D",
        "A",
        "B",
        "A",
        "C",
        "A",
        "C",
        "A",
        "C",
        "D",
        "C",
        "D",
        "B",
        "A",
        "A",
        "D",
        "A",
        "D",
        "B",
        "C",
        "A",
        "C",
        "D",
        "A",
        "A",
        "D",
        "B",
        "C",
        "A",
        "D",
        "C",
        "D",
        "A",
        "C",
        "D",
        "D",
        "A",
        "C",
        "D",
        "C",
        "A",
        "A",
        "C",
        "D",
        "A",
        "A",
        "A",
        "A",
        "B",
        "A",
        "A",
        "D",
        "D",
        "A",
        "A",
        "B",
        "A",
        "A",
        "D",
        "D",
        "D",
        "D",
        "A",
        "A",
        "D",
        "A",
        "A",
        "D",
        "C",
        "B",
        "B",
        "A",
        "A",
        "A",
        "A",
        "B",
        "C",
        "D",
        "D",
        "A",
        "A",
        "A",
        "C",
        "A",
        "A",
        "D",
        "B",
        "A",
        "B",
        "A",
        "C",
        "C",
        "A",
        "B",
        "C",
        "A"
    ]
})

# %%
df["y"].describe()
# Out:
# count    100.000000
# mean       2.380024
# std        3.287247
# min        0.068933
# 25%        0.484142
# 50%        1.087761
# 75%        2.723722
# max       17.586184
# Name: y, dtype: float64

# %%
df["x"].describe()
# Out:
# count     100
# unique      4
# top         A
# freq       46
# Name: x, dtype: object

# %%
model = bambi.Model(
    "y ~ x",
    df,
    family="wald"
)

results = model.build()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4d8b3b7aee96> in <module>
#       2     "y ~ x",
#       3     df,
# ----> 4     family="wald"
#       5 )
#       6
#
# ~/.conda/envs/2021-06-10T22.32.37_neilpquinn-wmf/lib/python3.7/site-packages/bambi/models.py in __init__(self, formula, data, family, priors, link, categorical, dropna, auto_scale, default_priors, noncentered, taylor)
#     176
#     177         # Build priors
# --> 178         self._build_priors()
#     179
#     180     def fit(
#
# ~/.conda/envs/2021-06-10T22.32.37_neilpquinn-wmf/lib/python3.7/site-packages/bambi/models.py in _build_priors(self)
#     321                 taylor = 5 if self.family.name == "gaussian" else 1
#     322             scaler = PriorScaler(self, taylor=taylor)
# --> 323             scaler.scale()
#     324
# ...

# %%
# %load_ext watermark

# %%
# %watermark -iv -v -m
# Out:
# Python implementation: CPython
# Python version       : 3.7.10
# IPython version      : 7.22.0
#
# Compiler    : GCC 7.5.0
# OS          : Linux
# Release     : 5.8.0-0.bpo.2-amd64
# Machine     : x86_64
# Processor   :
# CPU cores   : 32
# Architecture: 64bit
#
# pandas: 1.2.2
# bambi : 0.5.0
