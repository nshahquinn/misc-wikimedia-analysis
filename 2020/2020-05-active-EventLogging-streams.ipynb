# %%
from math import floor

import wmfdata as wmf
from wmfdata.utils import pd_display_all

# We assess activity by looking at the number of Hive partitions from the most recent month
MOST_RECENT_MO = 5

# %%
eventlogging_tables = wmf.spark.run("SHOW TABLES IN event").query(
  # Edit table is broken somehow, and inactive anyway
  "tableName != 'edit' &"
  # These tables come from the Modern Event Platform
    "~tableName.str.contains('mediawiki_') &"
    "~tableName.str.contains('eventgate_') &"
    "tableName not in ('resource_change')"
).reset_index(drop=True)

# %%
def get_partition_count(table_name):
  partitions_query = "SHOW PARTITIONS event.{} PARTITION(month='{}')".format(table_name, MOST_RECENT_MO)
  partitions = wmf.spark.run(partitions_query)
  return len(partitions)

eventlogging_tables["last_mo_partitions"] = eventlogging_tables["tableName"].apply(get_partition_count)

# %%
max_partitions = eventlogging_tables["last_mo_partitions"].max()
active_threshold = floor(max_partitions / 2)

active_tables = eventlogging_tables.query("last_mo_partitions >= @active_threshold")

# %% [markdown]
# These should all be included in the list of active schemas.

# %%
active_tables["tableName"].pipe(pd_display_all)
# Out:
# 0      advancedsearchrequest
# 2      centralauth
# 3      centralnoticebannerhistory
# 4      centralnoticeimpression
# 5      centralnoticetiming
# 7      changeslistfiltergrouping
# 9      changeslisthighlights
# 13     contenttranslation
# 14     contenttranslationabusefilter
# 15     contenttranslationcta
# 16     contenttranslationerror
# 17     contenttranslationsuggestion
# 18     cpubenchmark
# 19     echointeraction
# 20     echomail
# 21     editattemptstep
# 22     editconflict
# 23     editoractivation
# 24     editorjourney
# 28     eventerror
# 30     externalguidance
# 33     firstinputtiming
# 34     flowreplies
# 36     gettingstartedredirectimpression
# 37     guidedtourbuttonclick
# 38     guidedtourexited
# 39     guidedtourexternallinkactivation
# 40     guidedtourguiderhidden
# 41     guidedtourguiderimpression
# 43     helppanel
# 44     homepagemodule
# 45     homepagevisit
# 49     inukapageview
# 54     layoutshift
# 55     mediaviewer
# 56     mediawikipingback
# 64     mobilewebsearch
# 66     mobilewebuiactionstracking
# 68     mobilewikiappappearancesettings
# 69     mobilewikiapparticlesuggestions
# 70     mobilewikiappcreateaccount
# 71     mobilewikiappdailystats
# 72     mobilewikiappedit
# 73     mobilewikiappfeed
# 74     mobilewikiappfeedconfigure
# 75     mobilewikiappfindinpage
# 76     mobilewikiappinstallreferrer
# 77     mobilewikiappintents
# 79     mobilewikiappiosfeed
# 80     mobilewikiappiosloginaction
# 81     mobilewikiappiosreadinglists
# 82     mobilewikiappiossearch
# 83     mobilewikiappiossessions
# 84     mobilewikiappiossettingaction
# 85     mobilewikiappiosuserhistory
# 87     mobilewikiapplanguagesearching
# 88     mobilewikiapplanguagesettings
# 89     mobilewikiapplinkpreview
# 90     mobilewikiapplogin
# 91     mobilewikiappmediagallery
# 92     mobilewikiappnavmenu
# 93     mobilewikiappnotificationinteraction
# 94     mobilewikiappnotificationpreferences
# 97     mobilewikiapponthisday
# 98     mobilewikiapppagescroll
# 99     mobilewikiappprotectededitattempt
# 100    mobilewikiapprandomizer
# 101    mobilewikiappreadinglists
# 102    mobilewikiappsavedpages
# 103    mobilewikiappsearch
# 104    mobilewikiappsessions
# 105    mobilewikiappshareafact
# 107    mobilewikiappsuggestededits
# 108    mobilewikiapptabs
# 109    mobilewikiapptocinteraction
# 111    mobilewikiappwiktionarypopup
# 112    multimediaviewerattribution
# 113    multimediaviewerdimensions
# 114    multimediaviewerduration
# 115    multimediaviewernetworkperformance
# 117    navigationtiming
# 119    painttiming
# 120    popups
# 121    prefupdate
# 123    quicksurveyinitiation
# 124    quicksurveysresponses
# 127    referencepreviewsbaseline
# 128    referencepreviewscite
# 129    referencepreviewspopups
# 131    resourcetiming
# 132    rumspeedindex
# 133    savetiming
# 134    searchsatisfaction
# 135    searchsatisfactionerrors
# 136    serversideaccountcreation
# 137    servertiming
# 139    suggestedtagsaction
# 140    templatewizard
# 142    testsearchsatisfaction2
# 143    translationrecommendationapirequests
# 146    twocolconflictconflict
# 147    twocolconflictexit
# 148    universallanguageselector
# 149    uploadwizarderrorflowevent
# 150    uploadwizardexceptionflowevent
# 151    uploadwizardflowevent
# 152    uploadwizardstep
# 153    uploadwizardtutorialactions
# 154    uploadwizarduploadflowevent
# 156    virtualpageview
# 157    visualeditorfeatureuse
# 161    wikibasetermboxinteraction
# 162    wikidatacompletionsearchclicks
# 164    wikipediaportal
# 167    wmdebannerinteractions
# Name: tableName, dtype: object

# %% [markdown]
# Now, manually assess any schemas listed as active but not found in the list above. If they're truly inactive, they should be removed from the list, but keep in mind they also might represent rare events or have recently been implemented.
#
# The key question is whether the schema is used by the latest version of whatever codebase it applies to.
#
# One good way to check this is to search for the schema name with the [MediaWiki code search tool](https://codesearch.wmflabs.org). However, note the search doesn't cover the mobile apps and some other codebases that aren't part of MediaWiki.

# %%
extra_active_tables = [
  "guidedtourinternallinkactivation",
  "mobilewikiapplangselect",
  "mobilewikiappofflinelibrary",
  "mobilewikiapponboarding",
  "mobilewikiappwidgets",
  "translationrecommendationuirequests",
  "translationrecommendationuseraction",
  "wikimediablogvisit"
]

eventlogging_tables.query("tableName in @extra_active_tables")
# Out:
#     database                            tableName  isTemporary  \
# 42     event     guidedtourinternallinkactivation        False
# 86     event              mobilewikiapplangselect        False
# 95     event          mobilewikiappofflinelibrary        False
# 96     event              mobilewikiapponboarding        False
# 110    event                 mobilewikiappwidgets        False
# 144    event  translationrecommendationuirequests        False
# 145    event  translationrecommendationuseraction        False
# 163    event                   wikimediablogvisit        False
#
#      last_mo_partitions
# 42                   78
# 86                   66
# 95                    3
# 96                   45
# 110                  51
# 144                  72
# 145                  20
# 163                  14
