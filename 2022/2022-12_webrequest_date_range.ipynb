# %% [markdown]
# We retain data in the `webrequest` stream for 90 days, but in practice, what range of data do we have at any given time?

# %%
from datetime import datetime, timedelta, date

import wmfdata as wmf

wmf.spark.create_session(type="yarn-large")

# %% [markdown]
# The most recent data available:

# %%
print(f"Query started at {datetime.now().isoformat(sep=' ', timespec='minutes')}.")

newest = wmf.spark.run("""
SELECT
    year,
    month,
    day,
    hour,
    COUNT(*) AS records
FROM wmf.webrequest
WHERE
    year = 2022
    AND month = 12
    AND day = 9
GROUP BY
    year,
    month,
    day,
    hour
ORDER BY
    year,
    month,
    day,
    hour
""")
# Out:
# Query started at 2022-12-09 23:44.

# %% [markdown]
# It seems webrequest has data up until about an hour ago.

# %%
newest.style.format(formatter={"records": "{:,.0f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_96672">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96672_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_96672_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_96672_level0_col2" class="col_heading level0 col2" >day</th>
#       <th id="T_96672_level0_col3" class="col_heading level0 col3" >hour</th>
#       <th id="T_96672_level0_col4" class="col_heading level0 col4" >records</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96672_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96672_row0_col0" class="data row0 col0" >2022</td>
#       <td id="T_96672_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_96672_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_96672_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_96672_row0_col4" class="data row0 col4" >389,929,313</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96672_row1_col0" class="data row1 col0" >2022</td>
#       <td id="T_96672_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_96672_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_96672_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_96672_row1_col4" class="data row1 col4" >392,787,993</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96672_row2_col0" class="data row2 col0" >2022</td>
#       <td id="T_96672_row2_col1" class="data row2 col1" >12</td>
#       <td id="T_96672_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_96672_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_96672_row2_col4" class="data row2 col4" >395,662,013</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96672_row3_col0" class="data row3 col0" >2022</td>
#       <td id="T_96672_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_96672_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_96672_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_96672_row3_col4" class="data row3 col4" >376,748,217</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96672_row4_col0" class="data row4 col0" >2022</td>
#       <td id="T_96672_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_96672_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_96672_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_96672_row4_col4" class="data row4 col4" >357,351,573</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_96672_row5_col0" class="data row5 col0" >2022</td>
#       <td id="T_96672_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_96672_row5_col2" class="data row5 col2" >9</td>
#       <td id="T_96672_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_96672_row5_col4" class="data row5 col4" >365,745,780</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_96672_row6_col0" class="data row6 col0" >2022</td>
#       <td id="T_96672_row6_col1" class="data row6 col1" >12</td>
#       <td id="T_96672_row6_col2" class="data row6 col2" >9</td>
#       <td id="T_96672_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_96672_row6_col4" class="data row6 col4" >381,991,376</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96672_row7_col0" class="data row7 col0" >2022</td>
#       <td id="T_96672_row7_col1" class="data row7 col1" >12</td>
#       <td id="T_96672_row7_col2" class="data row7 col2" >9</td>
#       <td id="T_96672_row7_col3" class="data row7 col3" >7</td>
#       <td id="T_96672_row7_col4" class="data row7 col4" >409,908,555</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96672_row8_col0" class="data row8 col0" >2022</td>
#       <td id="T_96672_row8_col1" class="data row8 col1" >12</td>
#       <td id="T_96672_row8_col2" class="data row8 col2" >9</td>
#       <td id="T_96672_row8_col3" class="data row8 col3" >8</td>
#       <td id="T_96672_row8_col4" class="data row8 col4" >439,285,275</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_96672_row9_col0" class="data row9 col0" >2022</td>
#       <td id="T_96672_row9_col1" class="data row9 col1" >12</td>
#       <td id="T_96672_row9_col2" class="data row9 col2" >9</td>
#       <td id="T_96672_row9_col3" class="data row9 col3" >9</td>
#       <td id="T_96672_row9_col4" class="data row9 col4" >453,832,974</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_96672_row10_col0" class="data row10 col0" >2022</td>
#       <td id="T_96672_row10_col1" class="data row10 col1" >12</td>
#       <td id="T_96672_row10_col2" class="data row10 col2" >9</td>
#       <td id="T_96672_row10_col3" class="data row10 col3" >10</td>
#       <td id="T_96672_row10_col4" class="data row10 col4" >465,482,204</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_96672_row11_col0" class="data row11 col0" >2022</td>
#       <td id="T_96672_row11_col1" class="data row11 col1" >12</td>
#       <td id="T_96672_row11_col2" class="data row11 col2" >9</td>
#       <td id="T_96672_row11_col3" class="data row11 col3" >11</td>
#       <td id="T_96672_row11_col4" class="data row11 col4" >477,316,134</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_96672_row12_col0" class="data row12 col0" >2022</td>
#       <td id="T_96672_row12_col1" class="data row12 col1" >12</td>
#       <td id="T_96672_row12_col2" class="data row12 col2" >9</td>
#       <td id="T_96672_row12_col3" class="data row12 col3" >12</td>
#       <td id="T_96672_row12_col4" class="data row12 col4" >503,976,613</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_96672_row13_col0" class="data row13 col0" >2022</td>
#       <td id="T_96672_row13_col1" class="data row13 col1" >12</td>
#       <td id="T_96672_row13_col2" class="data row13 col2" >9</td>
#       <td id="T_96672_row13_col3" class="data row13 col3" >13</td>
#       <td id="T_96672_row13_col4" class="data row13 col4" >571,734,221</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_96672_row14_col0" class="data row14 col0" >2022</td>
#       <td id="T_96672_row14_col1" class="data row14 col1" >12</td>
#       <td id="T_96672_row14_col2" class="data row14 col2" >9</td>
#       <td id="T_96672_row14_col3" class="data row14 col3" >14</td>
#       <td id="T_96672_row14_col4" class="data row14 col4" >592,066,102</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_96672_row15_col0" class="data row15 col0" >2022</td>
#       <td id="T_96672_row15_col1" class="data row15 col1" >12</td>
#       <td id="T_96672_row15_col2" class="data row15 col2" >9</td>
#       <td id="T_96672_row15_col3" class="data row15 col3" >15</td>
#       <td id="T_96672_row15_col4" class="data row15 col4" >613,574,101</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_96672_row16_col0" class="data row16 col0" >2022</td>
#       <td id="T_96672_row16_col1" class="data row16 col1" >12</td>
#       <td id="T_96672_row16_col2" class="data row16 col2" >9</td>
#       <td id="T_96672_row16_col3" class="data row16 col3" >16</td>
#       <td id="T_96672_row16_col4" class="data row16 col4" >603,925,983</td>
#     </tr>
#     <tr>
#       <th id="T_96672_level0_row17" class="row_heading level0 row17" >17</th

# %%
now = datetime.now()

print(f"Query started at {now.isoformat(sep=' ', timespec='minutes')}.")
print(f"90 days ago was {(now - timedelta(days=90)).isoformat(sep=' ', timespec='minutes')}.")

oldest = wmf.spark.run("""
SELECT
    year,
    month,
    day,
    hour,
    COUNT(*) AS records
FROM wmf.webrequest
WHERE
    year = 2022
    AND month = 9
    AND day IN (9, 10, 11)
GROUP BY
    year,
    month,
    day,
    hour
ORDER BY
    year,
    month,
    day,
    hour
""")
# Out:
# Query started at 2022-12-09 23:45.
# 90 days ago was 2022-09-10 23:45.

# %% [markdown]
# Meanwhile, our oldest data goes back just a little further than exactly 90 days (3 hr, 45 min further, to be exact).

# %%
oldest.style.format(formatter={"records": "{:,.0f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_111da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_111da_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_111da_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_111da_level0_col2" class="col_heading level0 col2" >day</th>
#       <th id="T_111da_level0_col3" class="col_heading level0 col3" >hour</th>
#       <th id="T_111da_level0_col4" class="col_heading level0 col4" >records</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_111da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_111da_row0_col0" class="data row0 col0" >2022</td>
#       <td id="T_111da_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_111da_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_111da_row0_col3" class="data row0 col3" >20</td>
#       <td id="T_111da_row0_col4" class="data row0 col4" >528,095,803</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_111da_row1_col0" class="data row1 col0" >2022</td>
#       <td id="T_111da_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_111da_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_111da_row1_col3" class="data row1 col3" >21</td>
#       <td id="T_111da_row1_col4" class="data row1 col4" >471,909,319</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_111da_row2_col0" class="data row2 col0" >2022</td>
#       <td id="T_111da_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_111da_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_111da_row2_col3" class="data row2 col3" >22</td>
#       <td id="T_111da_row2_col4" class="data row2 col4" >413,512,281</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_111da_row3_col0" class="data row3 col0" >2022</td>
#       <td id="T_111da_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_111da_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_111da_row3_col3" class="data row3 col3" >23</td>
#       <td id="T_111da_row3_col4" class="data row3 col4" >370,561,948</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_111da_row4_col0" class="data row4 col0" >2022</td>
#       <td id="T_111da_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_111da_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_111da_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_111da_row4_col4" class="data row4 col4" >348,533,382</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_111da_row5_col0" class="data row5 col0" >2022</td>
#       <td id="T_111da_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_111da_row5_col2" class="data row5 col2" >11</td>
#       <td id="T_111da_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_111da_row5_col4" class="data row5 col4" >360,039,623</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_111da_row6_col0" class="data row6 col0" >2022</td>
#       <td id="T_111da_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_111da_row6_col2" class="data row6 col2" >11</td>
#       <td id="T_111da_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_111da_row6_col4" class="data row6 col4" >350,263,209</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_111da_row7_col0" class="data row7 col0" >2022</td>
#       <td id="T_111da_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_111da_row7_col2" class="data row7 col2" >11</td>
#       <td id="T_111da_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_111da_row7_col4" class="data row7 col4" >353,539,440</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_111da_row8_col0" class="data row8 col0" >2022</td>
#       <td id="T_111da_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_111da_row8_col2" class="data row8 col2" >11</td>
#       <td id="T_111da_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_111da_row8_col4" class="data row8 col4" >352,283,291</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_111da_row9_col0" class="data row9 col0" >2022</td>
#       <td id="T_111da_row9_col1" class="data row9 col1" >9</td>
#       <td id="T_111da_row9_col2" class="data row9 col2" >11</td>
#       <td id="T_111da_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_111da_row9_col4" class="data row9 col4" >355,502,095</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_111da_row10_col0" class="data row10 col0" >2022</td>
#       <td id="T_111da_row10_col1" class="data row10 col1" >9</td>
#       <td id="T_111da_row10_col2" class="data row10 col2" >11</td>
#       <td id="T_111da_row10_col3" class="data row10 col3" >6</td>
#       <td id="T_111da_row10_col4" class="data row10 col4" >382,059,080</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_111da_row11_col0" class="data row11 col0" >2022</td>
#       <td id="T_111da_row11_col1" class="data row11 col1" >9</td>
#       <td id="T_111da_row11_col2" class="data row11 col2" >11</td>
#       <td id="T_111da_row11_col3" class="data row11 col3" >7</td>
#       <td id="T_111da_row11_col4" class="data row11 col4" >416,023,562</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_111da_row12_col0" class="data row12 col0" >2022</td>
#       <td id="T_111da_row12_col1" class="data row12 col1" >9</td>
#       <td id="T_111da_row12_col2" class="data row12 col2" >11</td>
#       <td id="T_111da_row12_col3" class="data row12 col3" >8</td>
#       <td id="T_111da_row12_col4" class="data row12 col4" >446,602,397</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_111da_row13_col0" class="data row13 col0" >2022</td>
#       <td id="T_111da_row13_col1" class="data row13 col1" >9</td>
#       <td id="T_111da_row13_col2" class="data row13 col2" >11</td>
#       <td id="T_111da_row13_col3" class="data row13 col3" >9</td>
#       <td id="T_111da_row13_col4" class="data row13 col4" >460,088,058</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_111da_row14_col0" class="data row14 col0" >2022</td>
#       <td id="T_111da_row14_col1" class="data row14 col1" >9</td>
#       <td id="T_111da_row14_col2" class="data row14 col2" >11</td>
#       <td id="T_111da_row14_col3" class="data row14 col3" >10</td>
#       <td id="T_111da_row14_col4" class="data row14 col4" >475,358,204</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_111da_row15_col0" class="data row15 col0" >2022</td>
#       <td id="T_111da_row15_col1" class="data row15 col1" >9</td>
#       <td id="T_111da_row15_col2" class="data row15 col2" >11</td>
#       <td id="T_111da_row15_col3" class="data row15 col3" >11</td>
#       <td id="T_111da_row15_col4" class="data row15 col4" >505,579,246</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_111da_row16_col0" class="data row16 col0" >2022</td>
#       <td id="T_111da_row16_col1" class="data row16 col1" >9</td>
#       <td id="T_111da_row16_col2" class="data row16 col2" >11</td>
#       <td id="T_111da_row16_col3" class="data row16 col3" >12</td>
#       <td id="T_111da_row16_col4" class="data row16 col4" >544,518,620</td>
#     </tr>
#     <tr>
#       <th id="T_111da_level0_row17" class="row_heading level0 row17" >17</th

# %% [markdown]
# So what's the simplest strategy to run some analysis query across a predictable period that roughly matches what's available in webrequest?
#
# Spark (our most powerful query engine) cannot handle a query across all of webrequest, so we have to run a bunch of separate sub-period queries. Hourly queries are unnecessarily granular and would require a lot more logic to pick the starting and ending hours, so we want a range of calendar days to run daily queries against.
#
# Right now, `webrequest` contains data spanning from 2022-09-10 to 2022-12-09, which is *91* calendar days. So, if we cut off the two partial days at the beginning and end (90 days ago and today), we will have a period of 89 complete calendar days.
#
# For instance:

# %%
# We generated `now` this earlier, when we actually ran the queries
today = date(2022, 12, 9)

print(f"Start 89 days ago with {(today - timedelta(days=89)).isoformat()}.")
print(f"End yesterday with {(today - timedelta(days=1)).isoformat()}.")
# Out:
# Start 89 days ago with 2022-09-11.
# End yesterday with 2022-12-08.
